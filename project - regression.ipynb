# %%
import numpy as np
import pandas
import sklearn.model_selection
import sklearn.linear_model
import sklearn.metrics
import sklearn.preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_csv = pandas.read_csv("population.csv")
my_csv.replace(['--'], None, inplace=True)
my_csv = my_csv.dropna(how='any')

# %%
def linear_regression():
    X = my_csv[my_csv.columns.tolist()[1:-1]]
    y = my_csv[my_csv.columns.tolist()[-1]]
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y,test_size=0.2)
    linreg = sklearn.linear_model.LinearRegression()
    linreg.fit(X_train, y_train)
    y_pred = linreg.predict(X_test)
    canadax = my_csv.loc[my_csv['Country'] == 'Canada'].values.tolist()[0][1:-1]
    print(canadax)
    canada_2010 = my_csv.loc[my_csv['Country'] == 'Canada']['2010']
    print(my_csv.columns.tolist()[1:-1])
    plt.plot(my_csv.columns.tolist()[1:-1], canadax, 'o')
    plt.show()
    print(sklearn.metrics.mean_absolute_error(y_test, y_pred))
linear_regression()
# Out:
# ['24.5933', '24.9', '25.2019', '25.4563', '25.7018', '25.9416', '26.2038', '26.5497', '26.8948', '27.3793', '27.7906', '28.1179', '28.54489', '28.95334', '29.33081', '29.69053', '30.02632', '30.3056', '30.55166', '30.82026', '31.09956', '31.37674', '31.64096', '31.88931', '32.13476', '32.38638', '32.65668', '32.93596', '33.2127', '33.48721']
# 2    33.75974
# Name: 2010, dtype: object
# ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009']
# 0.03127705121560043

# %%
def tree_regression():
    X = my_csv[my_csv.columns.tolist()[1:-1]]
    y = my_csv[my_csv.columns.tolist()[-1]]
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.2)
    regressor = DecisionTreeRegressor()
    regressor.fit(X_train,y_train)
    y_pred = regressor.predict(X_test)
    print('Mean Absolute Error:', sklearn.metrics.mean_absolute_error(y_test, y_pred))

# %% [markdown]
# the better model was linear regression, probably beacause the data is very linear.
